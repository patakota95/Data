# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Basic Graph

# %%
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,10]

plt.plot(x,y)

plt.title('Our First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X Axis!')
plt.ylabel('Y Axis!')
plt.show()

# %%
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,10]

plt.plot(x,y, label='2x', linewidth=6, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

plt.title('Our First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X Axis!')
plt.ylabel('Y Axis!')

plt.xticks([0,1,2,3])
plt.yticks([0,2,4,6])

plt.legend()

plt.show()

# %%
x = [0,1,2,3,4,5]
y = [0,2,4,6,8,10]

#Resize your graph
plt.figure(figsize=(5,3), dpi=300)

#plt.plot(x,y, label='2x', linewidth=6, marker='.', linestyle='--', markersize=10, markeredgecolor='blue')

# Use shorthand notation
# fmt = '[color][marker][line]'
plt.plot(x,y, 'b^--', label='2x')

##Line number two
x2 = np.arange(0,4,0.5)
plt.plot(x2[:6], x2[:6]**2, 'r', label='X^2')
plt.plot(x2[5:], x2[5:]**2, 'r--')
#print(x2)



plt.title('Our First Graph!', fontdict={'fontname': 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X Axis!')
plt.ylabel('Y Axis!')

plt.xticks([0,1,2,3])
#plt.yticks([0,2,4,6])

plt.legend()

#plt.savefig('mygraph.png', dpi=300)

plt.show()

# %% [markdown]
# Bar Chart

# %%
labels = ['A', 'B', 'C']
values = [1,4,2]

bars = plt.bar(labels, values)

patterns = ['/', 'o', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
    
bars[0].set_hatch('/')
bars[1].set_hatch('o')
bars[2].set_hatch('*')

plt.figure(figsize=(6,4))

plt.show()
